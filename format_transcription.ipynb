# %%
import json
from datetime import timedelta

# %%
def format_time(seconds):
    """Convert seconds to MM:SS format"""
    minutes = int(seconds // 60)
    secs = int(seconds % 60)
    return f"{minutes:02d}:{secs:02d}"

# Load the JSON file
with open('output/cnbc oxychem sales_transcription_with_vicky_ref.json', 'r') as f:
    data = json.load(f)

segments = data['segments']
print(f"Total segments: {len(segments)}")

# %%
# Group continuous speaker segments
grouped_segments = []
current_speaker = None
current_start = None
current_end = None
current_text = []

for segment in segments:
    speaker = segment['speaker']
    
    if speaker == current_speaker:
        # Continue the current speaker's segment
        current_end = segment['end']
        current_text.append(segment['text'])
    else:
        # Save the previous speaker's segment if exists
        if current_speaker is not None:
            grouped_segments.append({
                'speaker': current_speaker,
                'start': current_start,
                'end': current_end,
                'text': ''.join(current_text)
            })
        
        # Start a new speaker segment
        current_speaker = speaker
        current_start = segment['start']
        current_end = segment['end']
        current_text = [segment['text']]

# Don't forget the last segment
if current_speaker is not None:
    grouped_segments.append({
        'speaker': current_speaker,
        'start': current_start,
        'end': current_end,
        'text': ''.join(current_text)
    })

print(f"Grouped into {len(grouped_segments)} continuous speaker segments")
# Out:
# Grouped into 12 continuous speaker segments

# %%
# Format the output
output_lines = []

for seg in grouped_segments:
    start_time = format_time(seg['start'])
    end_time = format_time(seg['end'])
    speaker = seg['speaker']
    text = seg['text'].strip()
    
    output_lines.append(f"{start_time} - {end_time} - Speaker {speaker}")
    output_lines.append(f'"{text}"')
    output_lines.append("")  # Empty line for spacing

# Preview first few segments
print("\n".join(output_lines[:20]))
# Out:
# 00:00 - 00:20 - Speaker A
# "Well, it's official. Berkshire Hathaway is acquiring Occidental's chemical business, OxyChem. It's an all-cash transaction. It's valued at $9.7 billion. And this is Berkshire's biggest purchase since 2022. Joining us right now is Vicki Hollett. She is Occidental Petroleum CEO. And Vicki, first of all, thanks for being here this morning. We appreciate it."
#
# 00:21 - 00:23 - Speaker Vicky Hollub
# "Thank you. I appreciate the opportunity, Becky."
#
# 00:23 - 00:30 - Speaker A
# "Let's talk a little bit about this deal, how it came together, and $9.7 billion in cash. What do you plan to do with it?"
#
# 00:31 - 01:07 - Speaker Vicky Hollub
# "Well, with the cash, we're going to take about $6.5 billion of the cash and we're going to apply it to debt reduction. And that debt reduction amount will get us to below our target debt of $15 billion that we laid out after the Crown Rock acquisition. That then will reduce our interest payments by $350 million. And that will enable us then to start adding back parts of our value proposition that we were not able to do. do previously. So now we're going to be able to start our share repurchase program again. So that's"
#
# 01:07 - 01:07 - Speaker A
# "Okay."
#
# 01:07 - 02:23 - Speaker Vicky Hollub
# "incredibly valuable for us. But the main reason we did this at this time is the timing was driven by the fact that the acquisition of Crown Rock enabled us to establish the Midland Basin as a core area. Once we established Midland as a core area, we were able to build a good Barnett position based on some appraisal work we've done on the Barnett previously. So to get that Barnett. position there and to also then take that Barnett knowledge and apply it to the Barnett that's underneath our conventional assets on the Central Basin platform. All of that enhanced our portfolio of oil and gas opportunities to the point where we have now decades of development opportunity in oil and gas. So we wanted to look at ways to accelerate value to our shareholders and again start that return. turn of capital back to our shareholders. Now our portfolio is the best it's ever been and we're applying our advanced technology and processes to make it even better. So really what this is doing is bringing forward value to our shareholders but also enabling us to do what we do best which ultimately creates even more value for our shareholders."
#
# 02:24 - 03:15 - Speaker A
# "Okay, let's talk a little bit through that for people who haven't been following along at home. long at home. You had a $12 billion acquisition that you just mentioned with Crown Rock last year. That's a U.S. shale producer that you were able to build this position up. That follows a $55 billion acquisition of Anadarko, which is another Permian Basin play that you completed back in 2019. So that was a lot of debt. You've been paying it down. I believe your goal was to get to $15 billion by 2027. So you'll be getting there earlier, assuming that this deal closes. in this quarter as I think the release lays out you're anticipating it'll close in the fourth quarter all of those plays with the Permian Basin do you feel like shareholders have appreciated that if we're looking at a five-year stock chart you're up 390 percent but over the last year it's been a little rougher you're down by close to 10 percent"

# %%
# Save to text file
output_path = 'output/cnbc oxychem sales_formatted.txt'
with open(output_path, 'w') as f:
    f.write("\n".join(output_lines))

print(f"Formatted transcription saved to {output_path}")
print(f"Total speaker segments: {len(grouped_segments)}")
# Out:
# Formatted transcription saved to output/cnbc oxychem sales_formatted.txt
# Total speaker segments: 12
